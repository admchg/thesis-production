# %%
import numpy as np
import pandas as pd

# %%
import string, re, unidecode

import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

from collections import Counter

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Read in

# %%
df_x = pd.read_csv("Data/dfx_nb0.csv", index_col = 0)
print(df_x.shape)
# Out:
# (172295, 25)

# %%
df_x['text'] = df_x['text'].fillna('')
df_x['textlower'] = df_x['text'].str.lower()
df_x['textlower'] = df_x['textlower'].str.replace('\n', ' ') # Replace all newlines

# %%
# Just for bottom print
df_x['title'] = df_x['title'].fillna('')

# %% [markdown]
# # Text processing

# %%
stemmer = SnowballStemmer('spanish')
remove_punc = str.maketrans('', '', string.punctuation)
stopwords_ascii = [unidecode.unidecode(w) for w in stopwords.words('spanish')]

def tokenize(s):
    s = unidecode.unidecode(s)
    s = s.translate(remove_punc)
    tokens = nltk.word_tokenize(s)
    filtered = [w for w in tokens if w not in stopwords_ascii]
    return [stemmer.stem(w) for w in filtered]

# %%
def dummy(x):
    return x

vectorizer = TfidfVectorizer(analyzer='word', tokenizer=dummy, preprocessor=dummy,
                            token_pattern=None)

# %%
df_t = df_x[df_x['textlower'].str.len() > 0]
print(df_t.shape)
# Out:
# (101797, 26)

# %% [markdown]
# ## Tokenize

# %%
df_t.loc[:,'token'] = df_t.loc[:,'textlower'].apply(tokenize)
# Out:
# //anaconda3/envs/vzwa/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# //anaconda3/envs/vzwa/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# Tokenize across all groups
def aggTokens(df):
    return df['token'].sum()

df_tgroup = df_t.groupby('uid').apply(aggTokens)

# %%
groups = sorted(df_t.uid.unique())
groups_titles = [df_x[df_x['uid'] == g]['title'].unique() for g in groups]

# %%
X = vectorizer.fit_transform(df_tgroup)
c = cosine_similarity(X)

# %%
def groupMsg(i):
    return df_x[df_x['uid'] == groups[i]]

def groupLatestDate(i):
    return groupMsg(i).sort_values('message_dt').iloc[-1]['message_dt']

trueCols = ['event', 'text', 'emojis',
       'audio_length', 'image', 'reply_to', 'reply_text', 'reply_image',
       'reply_thumb', 'reply_emojis', 'reply_type_audio', 'reply_type_image',
       'message_deleted', 'video_length', 'video_thumb', 'forwarded',
       'forwarded_highly', 'tel', 'message_dt', 'message_date', 'textlower']

# %% [markdown]
# ## Process similarities
#
# Match if one group contains 60\% of the other's messages (full inner merge)

# %%
rename_from_to = []

for i in zip(np.nonzero(c > 0.5)[0], np.nonzero(c > 0.5)[1]):
    if (i[0] >= i[1]):
        continue
    print(c[i[0], i[1]])
    print(i)
    print(groups[i[0]] + " / " + groups[i[1]])
    print(groups_titles[i[0]])
    print(groups_titles[i[1]])
    merge_size = pd.merge(groupMsg(i[0])[trueCols], groupMsg(i[1])[trueCols], how='inner').shape[0]
    
    if merge_size > 0.6 * min(groupMsg(i[0])[trueCols].shape[0], groupMsg(i[1])[trueCols].shape[0]) \
        and not (('-' in groups[i[0]]) and ('-' in groups[i[1]])):
        print("\nMERGE")
        
        if '-' in groups[i[0]]:
            rename_from_to.append((groups[i[1]], groups[i[0]]))
        elif '-' in groups[i[1]]:
            rename_from_to.append((groups[i[0]], groups[i[1]]))
        elif groupLatestDate(i[0]) >= groupLatestDate(i[1]):
            rename_from_to.append((groups[i[1]], groups[i[0]]))
        else:
            rename_from_to.append((groups[i[0]], groups[i[1]]))
    
    else:
        print()
        print(merge_size / min(groupMsg(i[0])[trueCols].shape[0], groupMsg(i[1])[trueCols].shape[0]))
        
    print()
# Out:
# 0.5410617395392494
# (1, 10)
# 07d5068cc56fa32bb22935edee3cf10a / 4057b3bafd4c6615ab55d292b8ca75f5
# ['VENEZOLANOS UNIDOS']
# ['VENEZOLANOS UNIDOS']
#
# MERGE
#
# 0.5352425151217718
# (2, 90)
# 0c069c3f9d40b1ab48639a0c0686dfc3 / 573185484739-1578495272
# ['VIAJES LATINOAMERICA 2']
# ['VIAJES LATINOAMERICA 2' 'VIAJES LATINOAMERICA 2…']
#
# MERGE
#
# 1.0
# (2, 162)
# 0c069c3f9d40b1ab48639a0c0686dfc3 / 5fec47ed4dc43982ac4e647aaecc48a2
# ['VIAJES LATINOAMERICA 2']
# ['VIAJES LATINOAMERICA 2']
#
# MERGE
#
# 0.9483070617207925
# (4, 6)
# 2a9efd099c8e26e3a8e189e617aa0e4a / 35c0a8c5a334567e7087db5c6c8d38c5
# ['COSTEÑOS CASEROS Y MAS']
# ['COSTEÑOS CASEROS Y MAS']
#
# MERGE
#
# 0.979125371764508
# (9, 149)
# 39c1800c883eff2c915903f30d38210d / 584245555958-1567221961
# ['Padres en Cúcuta']
# ['Show nay']
#
# MERGE
#
# 0.9106251233706617
# (11, 104)
# 43b1769e9012f53d9429819315f97f1f / 573212644564-1549511812
# ['StarCambioS']
# ['StarCambioS']
#
# MERGE
#
# 1.0
# (11, 167)
# 43b1769e9012f53d9429819315f97f1f / 85700215ac095301c08be263a8e96d4a
# ['StarCambioS']
# ['StarCambioS']
#
# MERGE
#
# 1.0
# (12, 37)
# 45bf41708fd0d8dfc698533ee378cf17 / 573014875618-1568166107
# ['En busca del amor']
# ['En busca del amor']
#
# MERGE
#
# 0.6371899976843463
# (12, 71)
# 45bf41708fd0d8dfc698533ee378cf17 / 573132354041-1558060453
# ['En busca del amor']
# ['El Renacimiento']
#
# 0.0
#
# 1.0
# (12, 168)
# 45bf41708fd0d8dfc698533ee378cf17 / 85b07927cac67371a7fad783185e3c98
# ['En busca del amor']
# ['En busca del amor']
#
# MERGE
#
# 1.0
# (12, 174)
# 45bf41708fd0d8dfc698533ee378cf17 / 98e09c58f6c8dadb5a0718470da8e78a
# ['En busca del amor']
# ['En busca del amor']
#
# 0.0
#
# 0.5071363299371358
# (12, 178)
# 45bf41708fd0d8dfc698533ee378cf17 / bb5f0162ea905c338130adedd4e0b703
# ['En busca del amor']
# ['Rumbas en Cali YAYI']
#
# 0.0
#
# 1.0
# (12, 182)
# 45bf41708fd0d8dfc698533ee378cf17 / c5b60e71e9324a17027931bab4014e86
# ['En busca del amor']
# ['En busca del amor']
#
# 0.0
#
# 1.0000000000000002
# (13, 14)
# 4c103772c5a599af3912a89af9879d32 / 4d6285a77139c02b4806bef63f57173f
# ['SEMINARIO DEL DÌLÓGÚN']
# ['SEMINARIO DEL DÌLÓGÚN']
#
# MERGE
#
# 0.6456056885246149
# (13, 29)
# 4c103772c5a599af3912a89af9879d32 / 573004963728-1580741715
# ['SEMINARIO DEL DÌLÓGÚN']
# ['SEMINARIO DÌLÓGÚN DE ÒŞÀ' 'SEMINARIO DÌLÓGÚN DE ÒŞÀ …'
#  'SEMINARIO DEL DÌLÓGÚN' 'SEMINARIO DEL DÌLÓGÚN …']
#
# MERGE
#
# 0.6456056885246149
# (14, 29)
# 4d6285a77139c02b4806bef63f57173f / 573004963728-1580741715
# ['SEMINARIO DEL DÌLÓGÚN']
# ['SEMINARIO DÌLÓGÚN DE ÒŞÀ' 'SEMINARIO DÌLÓGÚN DE ÒŞÀ …'
#  'SEMINARIO DEL DÌLÓGÚN' 'SEMINARIO DEL DÌLÓGÚN …']
#
# MERGE
#
# 0.8222359599675954
# (15, 34)
# 4e3e6b18ff97148283f4587c277993f9 / 573007430226-1578930907
# ['SAIME Tramita TU Cedula Pasaporte']
# ['SAIME Tramita TU Cedula Pasaporte']
#
# MERGE
#
# 0.5410595346807343
# (17, 21)
# 51917538984-1578626940 / 51974115898-1579148636
# ['VENEZOLANOS EN CUCUTA']
# ['AmorVenezuel@']
#
# 0.0
#
# 0.5288449860338617
# (17, 23)
# 51917538984-1578626940 / 51988040838-1584630026
# ['VENEZOLANOS EN CUCUTA']
# ['Conociendo Amistades Peru']
#
# 0.0
#
# 0.7584288330380906
# (17, 30)
# 51917538984-1578626940 / 573006401779-1563676942
# ['VENEZOLANOS EN CUCUTA']
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
#
# 0.0040595399188092015
#
# 0.7927677560234362
# (17, 43)
# 51917538984-1578626940 / 573105500196-1509907612
# ['VENEZOLANOS EN CUCUTA']
# ['VENEZOLANOS EN BOGOTÁ']
#
# 0.0
#
# 0.6728989219353817
# (17, 45)
# 51917538984-1578626940 / 573106687281-1572810835
# ['VENEZOLANOS EN CUCUTA']
# ['CONFORT SALUD']
#
# 0.0
#
# 0.5776564957388531
# (17, 48)
# 51917538984-1578626940 / 573107070227-1558586309
# ['VENEZOLANOS EN CUCUTA']
# ['Ahizer tours']
#
# 0.0
#
# 0.5602448436848807
# (17, 49)
# 51917538984-1578626940 / 573108189461-1574524235
# ['VENEZOLANOS EN CUCUTA']
# ['Venezolanos unidos en paz' 'Chamos' 'Venezolanos en Colombia']
#
# 0.0
#
# 0.737959507963703
# (17, 51)
# 51917538984-1578626940 / 573115240918-1554687011
# ['VENEZOLANOS EN CUCUTA']
# ['Agencia Miraflores']
#
# 0.0
#
# 0.5145912808871009
# (17, 53)
# 51917538984-1578626940 / 573116409370-1578664391
# ['VENEZOLANOS EN CUCUTA']
# ['videos & demencias']
#
# 0.0006931608133086876
#
# 0.6253874919414063
# (17, 58)
# 51917538984-1578626940 / 573118547343-1545866247
# ['VENEZOLANOS EN CUCUTA']
# ['ServicioViajeros JP &']
#
# 0.0
#
# 0.534603404531301
# (17, 65)
# 51917538984-1578626940 / 573124347578-1563538654
# ['VENEZOLANOS EN CUCUTA']
# ['41RED DE APOYO']
#
# 0.0
#
# 0.5175751883229015
# (17, 69)
# 51917538984-1578626940 / 573126571743-1576515287
# ['VENEZOLANOS EN CUCUTA']
# ['Venezuela Hermosa']
#
# 0.0
#
# 0.6043762518882001
# (17, 73)
# 51917538984-1578626940 / 573134508951-1549727034
# ['VENEZOLANOS EN CUCUTA']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.5076942475302568
# (17, 74)
# 51917538984-1578626940 / 573135714229-1525652805
# ['VENEZOLANOS EN CUCUTA']
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
#
# 0.0
#
# 0.7758100520387425
# (17, 78)
# 51917538984-1578626940 / 573138303724-1574641574
# ['VENEZOLANOS EN CUCUTA']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.577759882486655
# (17, 80)
# 51917538984-1578626940 / 573144119145-1579414437
# ['VENEZOLANOS EN CUCUTA']
# ['VENEZOLANOS UNIDOS' 'VENEZOLANOS UNIDOS…']
#
# 0.0
#
# 0.5461738701097592
# (17, 81)
# 51917538984-1578626940 / 573145114610-1573649691
# ['VENEZOLANOS EN CUCUTA']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5367779297626334
# (17, 98)
# 51917538984-1578626940 / 573204896999-1557775885
# ['VENEZOLANOS EN CUCUTA']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.5089646593087996
# (17, 101)
# 51917538984-1578626940 / 573209056220-1582183315
# ['VENEZOLANOS EN CUCUTA']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.5202236956674006
# (17, 118)
# 51917538984-1578626940 / 573227727724-1572791992
# ['VENEZOLANOS EN CUCUTA']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.5831305882019617
# (17, 121)
# 51917538984-1578626940 / 573507846957-1571104076
# ['VENEZOLANOS EN CUCUTA']
# ['Viajando por america' 'Viajando por america…' 'viaja con yoeslin']
#
# 0.0
#
# 0.665592054520274
# (17, 122)
# 51917538984-1578626940 / 573508650959-1572285131
# ['VENEZOLANOS EN CUCUTA']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6344655501128573
# (17, 126)
# 51917538984-1578626940 / 584124411924-1570375550
# ['VENEZOLANOS EN CUCUTA']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5836824040894063
# (17, 128)
# 51917538984-1578626940 / 584126397289-1585051205
# ['VENEZOLANOS EN CUCUTA']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.6413449206359438
# (17, 130)
# 51917538984-1578626940 / 584143426635-1560226365
# ['VENEZOLANOS EN CUCUTA']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.00014762326542663124
#
# 0.5726127484293879
# (17, 131)
# 51917538984-1578626940 / 584144043691-1548595172
# ['VENEZOLANOS EN CUCUTA']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5511284211956388
# (17, 137)
# 51917538984-1578626940 / 584164805353-1497744666
# ['VENEZOLANOS EN CUCUTA']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.6700816471406982
# (17, 152)
# 51917538984-1578626940 / 584246899964-1572440568
# ['VENEZOLANOS EN CUCUTA']
# ['Venezolanos por migrar']
#
# 0.0
#
# 0.5232906661397746
# (17, 154)
# 51917538984-1578626940 / 584247393733-1565574033
# ['VENEZOLANOS EN CUCUTA']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.523291547378951
# (17, 161)
# 51917538984-1578626940 / 584264954187-1584036417
# ['VENEZOLANOS EN CUCUTA']
# ['Salsa baul.']
#
# 0.0
#
# 0.9195034632706077
# (19, 41)
# 51955257649-1554235320 / 573022311419-1550941945
# ['🅶🅸🅲 Colombia']
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
#
# 0.0
#
# 0.7723222767937193
# (19, 73)
# 51955257649-1554235320 / 573134508951-1549727034
# ['🅶🅸🅲 Colombia']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.5877092279904913
# (19, 118)
# 51955257649-1554235320 / 573227727724-1572791992
# ['🅶🅸🅲 Colombia']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.5364583871023568
# (19, 126)
# 51955257649-1554235320 / 584124411924-1570375550
# ['🅶🅸🅲 Colombia']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.6874086513999559
# (19, 128)
# 51955257649-1554235320 / 584126397289-1585051205
# ['🅶🅸🅲 Colombia']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.7605965621759677
# (19, 129)
# 51955257649-1554235320 / 584126863708-1574171158
# ['🅶🅸🅲 Colombia']
# ['Venezuela Al Minuto XXXIV']
#
# 0.0
#
# 0.7970180773885773
# (19, 130)
# 51955257649-1554235320 / 584143426635-1560226365
# ['🅶🅸🅲 Colombia']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.8746690685077179
# (19, 131)
# 51955257649-1554235320 / 584144043691-1548595172
# ['🅶🅸🅲 Colombia']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.7440087866666653
# (19, 137)
# 51955257649-1554235320 / 584164805353-1497744666
# ['🅶🅸🅲 Colombia']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5784436670218303
# (20, 126)
# 51966972481-1543878905 / 584124411924-1570375550
# ['INFORMACIÓNVERAS…' 'INFORMACIÓNVERAS']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.507405342243088
# (21, 25)
# 51974115898-1579148636 / 5516993479730-1579098756
# ['AmorVenezuel@']
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# 0.0
#
# 0.5725794587866898
# (21, 53)
# 51974115898-1579148636 / 573116409370-1578664391
# ['AmorVenezuel@']
# ['videos & demencias']
#
# 0.0
#
# 0.5286263323707939
# (21, 74)
# 51974115898-1579148636 / 573135714229-1525652805
# ['AmorVenezuel@']
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
#
# 0.0
#
# 0.5482196854357848
# (21, 75)
# 51974115898-1579148636 / 573135852009-1585347056
# ['AmorVenezuel@']
# ['Lakrasy fresasde vnzla' 'Hora hott' 'Lakrasy fresas de vnzl'
#  '.Supreme 5.0']
#
# 0.0
#
# 0.6615234977715284
# (21, 81)
# 51974115898-1579148636 / 573145114610-1573649691
# ['AmorVenezuel@']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5342052121773815
# (21, 98)
# 51974115898-1579148636 / 573204896999-1557775885
# ['AmorVenezuel@']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.6106172685127569
# (21, 101)
# 51974115898-1579148636 / 573209056220-1582183315
# ['AmorVenezuel@']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.5715551769251878
# (21, 154)
# 51974115898-1579148636 / 584247393733-1565574033
# ['AmorVenezuel@']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.602154070438855
# (21, 161)
# 51974115898-1579148636 / 584264954187-1584036417
# ['AmorVenezuel@']
# ['Salsa baul.']
#
# 0.0
#
# 0.5404461502939769
# (22, 23)
# 51988040838-1565555250 / 51988040838-1584630026
# ['Eventos y amistades']
# ['Conociendo Amistades Peru']
#
# 0.012162162162162163
#
# 0.5309617382856222
# (23, 30)
# 51988040838-1584630026 / 573006401779-1563676942
# ['Conociendo Amistades Peru']
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
#
# 0.0
#
# 0.5412587516214037
# (23, 43)
# 51988040838-1584630026 / 573105500196-1509907612
# ['Conociendo Amistades Peru']
# ['VENEZOLANOS EN BOGOTÁ']
#
# 0.0
#
# 0.5014551320566203
# (23, 74)
# 51988040838-1584630026 / 573135714229-1525652805
# ['Conociendo Amistades Peru']
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
#
# 0.0
#
# 0.5455522789040594
# (23, 78)
# 51988040838-1584630026 / 573138303724-1574641574
# ['Conociendo Amistades Peru']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5335028572683428
# (23, 81)
# 51988040838-1584630026 / 573145114610-1573649691
# ['Conociendo Amistades Peru']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5198430988428758
# (25, 81)
# 5516993479730-1579098756 / 573145114610-1573649691
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.6871952584337657
# (25, 82)
# 5516993479730-1579098756 / 573148456866-1573071471
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# ['༒⃢⃟ music^']
#
# 0.0
#
# 0.5579737439021952
# (25, 101)
# 5516993479730-1579098756 / 573209056220-1582183315
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# ['SalsaBaul ineditas']
#
# 0.0024923843810578787
#
# 0.5132052731171727
# (25, 134)
# 5516993479730-1579098756 / 584147263552-1575732464
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# ['Música electrónica']
#
# 0.0
#
# 0.5873228212339493
# (25, 160)
# 5516993479730-1579098756 / 584264117981-1585540851
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# ['VERDAD O RETO' '*VERDAD O RETO*' 'Verdad o RETO']
#
# 0.0
#
# 0.5250492908129877
# (25, 161)
# 5516993479730-1579098756 / 584264954187-1584036417
# ['Salsa para las lacras' 'Salsa y electro para las lacras'
#  'Elde la salsa para las' 'Salsa y en Alta']
# ['Salsa baul.']
#
# 0.0003181673560292714
#
# 0.8177623960845555
# (30, 43)
# 573006401779-1563676942 / 573105500196-1509907612
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['VENEZOLANOS EN BOGOTÁ']
#
# 0.007668019846639603
#
# 0.6712780236308076
# (30, 45)
# 573006401779-1563676942 / 573106687281-1572810835
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['CONFORT SALUD']
#
# 0.0
#
# 0.6262128894929305
# (30, 49)
# 573006401779-1563676942 / 573108189461-1574524235
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Venezolanos unidos en paz' 'Chamos' 'Venezolanos en Colombia']
#
# 0.0017889087656529517
#
# 0.6828695039347145
# (30, 51)
# 573006401779-1563676942 / 573115240918-1554687011
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Agencia Miraflores']
#
# 0.0
#
# 0.5475992157745643
# (30, 58)
# 573006401779-1563676942 / 573118547343-1545866247
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['ServicioViajeros JP &']
#
# 0.0
#
# 0.5591725132134876
# (30, 63)
# 573006401779-1563676942 / 573123412936-1556628265
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Informa Vzla']
#
# 0.0
#
# 0.5513314154194934
# (30, 65)
# 573006401779-1563676942 / 573124347578-1563538654
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['41RED DE APOYO']
#
# 0.0
#
# 0.5798520539912215
# (30, 69)
# 573006401779-1563676942 / 573126571743-1576515287
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Venezuela Hermosa']
#
# 0.0
#
# 0.5654760430427718
# (30, 73)
# 573006401779-1563676942 / 573134508951-1549727034
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.5049887543229737
# (30, 74)
# 573006401779-1563676942 / 573135714229-1525652805
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
#
# 0.0
#
# 0.8006052734812407
# (30, 78)
# 573006401779-1563676942 / 573138303724-1574641574
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.565079053587814
# (30, 80)
# 573006401779-1563676942 / 573144119145-1579414437
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['VENEZOLANOS UNIDOS' 'VENEZOLANOS UNIDOS…']
#
# 0.0007930214115781126
#
# 0.5089377350328584
# (30, 81)
# 573006401779-1563676942 / 573145114610-1573649691
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5165560105882244
# (30, 98)
# 573006401779-1563676942 / 573204896999-1557775885
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.5445768977918813
# (30, 105)
# 573006401779-1563676942 / 573213514329-1575474764
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['El Mercadito Venezolano']
#
# 0.0
#
# 0.503706813813605
# (30, 118)
# 573006401779-1563676942 / 573227727724-1572791992
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.6504943588117166
# (30, 122)
# 573006401779-1563676942 / 573508650959-1572285131
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6581926723500254
# (30, 126)
# 573006401779-1563676942 / 584124411924-1570375550
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5672243213587339
# (30, 128)
# 573006401779-1563676942 / 584126397289-1585051205
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.5968341881163209
# (30, 130)
# 573006401779-1563676942 / 584143426635-1560226365
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.5524935690751669
# (30, 131)
# 573006401779-1563676942 / 584144043691-1548595172
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5367092427427618
# (30, 137)
# 573006401779-1563676942 / 584164805353-1497744666
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5839724490096426
# (30, 152)
# 573006401779-1563676942 / 584246899964-1572440568
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Venezolanos por migrar']
# 0.0
#
# 0.520517994433519
# (30, 154)
# 573006401779-1563676942 / 584247393733-1565574033
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.5004819142682124
# (30, 161)
# 573006401779-1563676942 / 584264954187-1584036417
# ['EMPLEO VENEZOLANOS' 'EMPLEO VENEZOLANOS…' 'Venezolanos unidos'
#  'EN CUARENTENA']
# ['Salsa baul.']
#
# 0.0
#
# 0.5901236230009873
# (33, 56)
# 573006632902-1573570307 / 573118275688-1574895740
# ['Buenas amistades']
# ['XXX CASEROS Y MAS']
#
# 0.0
#
# 0.5231566604226654
# (33, 81)
# 573006632902-1573570307 / 573145114610-1573649691
# ['Buenas amistades']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5795481801576345
# (33, 120)
# 573006632902-1573570307 / 573505077552-1573850475
# ['Buenas amistades']
# ['Venezuela']
#
# 0.0
#
# 0.6371899976843463
# (37, 71)
# 573014875618-1568166107 / 573132354041-1558060453
# ['En busca del amor']
# ['El Renacimiento']
#
# 0.0
#
# 1.0
# (37, 168)
# 573014875618-1568166107 / 85b07927cac67371a7fad783185e3c98
# ['En busca del amor']
# ['En busca del amor']
#
# MERGE
#
# 1.0
# (37, 174)
# 573014875618-1568166107 / 98e09c58f6c8dadb5a0718470da8e78a
# ['En busca del amor']
# ['En busca del amor']
#
# 0.0
#
# 0.5071363299371358
# (37, 178)
# 573014875618-1568166107 / bb5f0162ea905c338130adedd4e0b703
# ['En busca del amor']
# ['Rumbas en Cali YAYI']
#
# 0.0
#
# 1.0
# (37, 182)
# 573014875618-1568166107 / c5b60e71e9324a17027931bab4014e86
# ['En busca del amor']
# ['En busca del amor']
#
# 0.0
#
# 0.5914825101945833
# (38, 97)
# 573015048048-1575221610 / 573204379940-1516889957
# ['☆ғᴀsᴛ ᴛʀᴀɴsғᴇʀ ɢʀᴜᴘᴏ #3☆']
# ['Nacional de Cambios  .']
#
# 0.0
#
# 0.6365489403683777
# (38, 151)
# 573015048048-1575221610 / 584246249002-1565349721
# ['☆ғᴀsᴛ ᴛʀᴀɴsғᴇʀ ɢʀᴜᴘᴏ #3☆']
# ['CASA DE CAMBIOS D&Y' 'CASA DE CAMBIOS D&Y…']
#
# 0.0
#
# 0.5281560159903776
# (39, 40)
# 573017993751-1569048296 / 573017993751-1571204832
# ['Solo Alerta']
# ['Solo Alerta 2.0']
#
# 0.03203125
#
# 0.835304602271987
# (41, 73)
# 573022311419-1550941945 / 573134508951-1549727034
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.6285881249794039
# (41, 118)
# 573022311419-1550941945 / 573227727724-1572791992
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.5142208097593004
# (41, 122)
# 573022311419-1550941945 / 573508650959-1572285131
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.5935691673737304
# (41, 126)
# 573022311419-1550941945 / 584124411924-1570375550
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.7388533112183853
# (41, 128)
# 573022311419-1550941945 / 584126397289-1585051205
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.7682310859850732
# (41, 129)
# 573022311419-1550941945 / 584126863708-1574171158
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['Venezuela Al Minuto XXXIV']
#
# 0.0
#
# 0.8401509573582936
# (41, 130)
# 573022311419-1550941945 / 584143426635-1560226365
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.8805853515652704
# (41, 131)
# 573022311419-1550941945 / 584144043691-1548595172
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.7803117499706238
# (41, 137)
# 573022311419-1550941945 / 584164805353-1497744666
# ['#1 NOTICIAS VENEZUELA…' '#1 NOTICIAS VENEZUELA']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.6583273083106447
# (43, 45)
# 573105500196-1509907612 / 573106687281-1572810835
# ['VENEZOLANOS EN BOGOTÁ']
# ['CONFORT SALUD']
#
# 0.0
#
# 0.6096862088359509
# (43, 49)
# 573105500196-1509907612 / 573108189461-1574524235
# ['VENEZOLANOS EN BOGOTÁ']
# ['Venezolanos unidos en paz' 'Chamos' 'Venezolanos en Colombia']
#
# 0.0
#
# 0.6758015376600814
# (43, 51)
# 573105500196-1509907612 / 573115240918-1554687011
# ['VENEZOLANOS EN BOGOTÁ']
# ['Agencia Miraflores']
#
# 0.0
#
# 0.5517775048125495
# (43, 58)
# 573105500196-1509907612 / 573118547343-1545866247
# ['VENEZOLANOS EN BOGOTÁ']
# ['ServicioViajeros JP &']
#
# 0.0
#
# 0.5012330744913783
# (43, 63)
# 573105500196-1509907612 / 573123412936-1556628265
# ['VENEZOLANOS EN BOGOTÁ']
# ['Informa Vzla']
#
# 0.0
#
# 0.5503580930066257
# (43, 65)
# 573105500196-1509907612 / 573124347578-1563538654
# ['VENEZOLANOS EN BOGOTÁ']
# ['41RED DE APOYO']
#
# 0.0
#
# 0.584050307086676
# (43, 69)
# 573105500196-1509907612 / 573126571743-1576515287
# ['VENEZOLANOS EN BOGOTÁ']
# ['Venezuela Hermosa']
#
# 0.0
#
# 0.6170556364328476
# (43, 73)
# 573105500196-1509907612 / 573134508951-1549727034
# ['VENEZOLANOS EN BOGOTÁ']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.5054506179170886
# (43, 74)
# 573105500196-1509907612 / 573135714229-1525652805
# ['VENEZOLANOS EN BOGOTÁ']
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
#
# 0.0
#
# 0.8179485132899595
# (43, 78)
# 573105500196-1509907612 / 573138303724-1574641574
# ['VENEZOLANOS EN BOGOTÁ']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5490781661701863
# (43, 80)
# 573105500196-1509907612 / 573144119145-1579414437
# ['VENEZOLANOS EN BOGOTÁ']
# ['VENEZOLANOS UNIDOS' 'VENEZOLANOS UNIDOS…']
#
# 0.0
#
# 0.5088044111978545
# (43, 81)
# 573105500196-1509907612 / 573145114610-1573649691
# ['VENEZOLANOS EN BOGOTÁ']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5201643506349702
# (43, 98)
# 573105500196-1509907612 / 573204896999-1557775885
# ['VENEZOLANOS EN BOGOTÁ']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.5241480877649428
# (43, 105)
# 573105500196-1509907612 / 573213514329-1575474764
# ['VENEZOLANOS EN BOGOTÁ']
# ['El Mercadito Venezolano']
#
# 0.0
#
# 0.5232225244945432
# (43, 118)
# 573105500196-1509907612 / 573227727724-1572791992
# ['VENEZOLANOS EN BOGOTÁ']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.6456363313860641
# (43, 122)
# 573105500196-1509907612 / 573508650959-1572285131
# ['VENEZOLANOS EN BOGOTÁ']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6303850532204183
# (43, 126)
# 573105500196-1509907612 / 584124411924-1570375550
# ['VENEZOLANOS EN BOGOTÁ']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5945632880007493
# (43, 128)
# 573105500196-1509907612 / 584126397289-1585051205
# ['VENEZOLANOS EN BOGOTÁ']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.6374925221873883
# (43, 130)
# 573105500196-1509907612 / 584143426635-1560226365
# ['VENEZOLANOS EN BOGOTÁ']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.590803482090643
# (43, 131)
# 573105500196-1509907612 / 584144043691-1548595172
# ['VENEZOLANOS EN BOGOTÁ']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.566609640751281
# (43, 137)
# 573105500196-1509907612 / 584164805353-1497744666
# ['VENEZOLANOS EN BOGOTÁ']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.613058081461839
# (43, 152)
# 573105500196-1509907612 / 584246899964-1572440568
# ['VENEZOLANOS EN BOGOTÁ']
# ['Venezolanos por migrar']
#
# 0.0
#
# 0.5134550603335489
# (43, 154)
# 573105500196-1509907612 / 584247393733-1565574033
# ['VENEZOLANOS EN BOGOTÁ']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.7451205730630658
# (44, 156)
# 573106499958-1529031886 / 584247622382-1574092989
# ['CAMBIOS PIPE AL 0.0495' 'CAMBIOS PIPE AL 0.0495…']
# ['COMPRAVENTAVZLA']
#
# 0.3125
#
# 0.5104589598495894
# (45, 49)
# 573106687281-1572810835 / 573108189461-1574524235
# ['CONFORT SALUD']
# ['Venezolanos unidos en paz' 'Chamos' 'Venezolanos en Colombia']
#
# 0.0
#
# 0.6359778720056793
# (45, 51)
# 573106687281-1572810835 / 573115240918-1554687011
# ['CONFORT SALUD']
# ['Agencia Miraflores']
#
# 0.0
#
# 0.5832136048140825
# (45, 61)
# 573106687281-1572810835 / 573122152386-1579230646
# ['CONFORT SALUD']
# ['Venezolanos panas' 'Las fresas']
#
# 0.0
#
# 0.5294102535884648
# (45, 63)
# 573106687281-1572810835 / 573123412936-1556628265
# ['CONFORT SALUD']
# ['Informa Vzla']
#
# 0.0
#
# 0.5224997481106926
# (45, 73)
# 573106687281-1572810835 / 573134508951-1549727034
# ['CONFORT SALUD']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.6348021286242824
# (45, 78)
# 573106687281-1572810835 / 573138303724-1574641574
# ['CONFORT SALUD']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5808962852768668
# (45, 122)
# 573106687281-1572810835 / 573508650959-1572285131
# ['CONFORT SALUD']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6068770542403524
# (45, 126)
# 573106687281-1572810835 / 584124411924-1570375550
# ['CONFORT SALUD']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.507923593735963
# (45, 128)
# 573106687281-1572810835 / 584126397289-1585051205
# ['CONFORT SALUD']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.5383803361115413
# (45, 130)
# 573106687281-1572810835 / 584143426635-1560226365
# ['CONFORT SALUD']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
# 0.0
#
# 0.5156958491908149
# (45, 131)
# 573106687281-1572810835 / 584144043691-1548595172
# ['CONFORT SALUD']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5229477042786147
# (48, 51)
# 573107070227-1558586309 / 573115240918-1554687011
# ['Ahizer tours']
# ['Agencia Miraflores']
#
# 0.0
#
# 0.5472663822015532
# (48, 58)
# 573107070227-1558586309 / 573118547343-1545866247
# ['Ahizer tours']
# ['ServicioViajeros JP &']
#
# 0.0
#
# 0.5566580480121245
# (48, 90)
# 573107070227-1558586309 / 573185484739-1578495272
# ['Ahizer tours']
# ['VIAJES LATINOAMERICA 2' 'VIAJES LATINOAMERICA 2…']
#
# 0.0
#
# 0.5825021935788697
# (48, 121)
# 573107070227-1558586309 / 573507846957-1571104076
# ['Ahizer tours']
# ['Viajando por america' 'Viajando por america…' 'viaja con yoeslin']
#
# 0.0
#
# 0.5564428880764904
# (49, 78)
# 573108189461-1574524235 / 573138303724-1574641574
# ['Venezolanos unidos en paz' 'Chamos' 'Venezolanos en Colombia']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5874855489559881
# (51, 58)
# 573115240918-1554687011 / 573118547343-1545866247
# ['Agencia Miraflores']
# ['ServicioViajeros JP &']
#
# 0.0
#
# 0.5741880954444473
# (51, 63)
# 573115240918-1554687011 / 573123412936-1556628265
# ['Agencia Miraflores']
# ['Informa Vzla']
#
# 0.0
#
# 0.503418439647737
# (51, 69)
# 573115240918-1554687011 / 573126571743-1576515287
# ['Agencia Miraflores']
# ['Venezuela Hermosa']
#
# 0.0
#
# 0.5686720835313062
# (51, 73)
# 573115240918-1554687011 / 573134508951-1549727034
# ['Agencia Miraflores']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.6543864406542319
# (51, 78)
# 573115240918-1554687011 / 573138303724-1574641574
# ['Agencia Miraflores']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5171406723922983
# (51, 118)
# 573115240918-1554687011 / 573227727724-1572791992
# ['Agencia Miraflores']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.5055138705102978
# (51, 121)
# 573115240918-1554687011 / 573507846957-1571104076
# ['Agencia Miraflores']
# ['Viajando por america' 'Viajando por america…' 'viaja con yoeslin']
#
# 0.0
#
# 0.6521510253749333
# (51, 122)
# 573115240918-1554687011 / 573508650959-1572285131
# ['Agencia Miraflores']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.7025981336207735
# (51, 126)
# 573115240918-1554687011 / 584124411924-1570375550
# ['Agencia Miraflores']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5613904868120109
# (51, 128)
# 573115240918-1554687011 / 584126397289-1585051205
# ['Agencia Miraflores']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.6085931920710725
# (51, 130)
# 573115240918-1554687011 / 584143426635-1560226365
# ['Agencia Miraflores']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.5745953609526154
# (51, 131)
# 573115240918-1554687011 / 584144043691-1548595172
# ['Agencia Miraflores']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5591977111201623
# (51, 137)
# 573115240918-1554687011 / 584164805353-1497744666
# ['Agencia Miraflores']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5320263362938845
# (51, 152)
# 573115240918-1554687011 / 584246899964-1572440568
# ['Agencia Miraflores']
# ['Venezolanos por migrar']
#
# 0.0
#
# 0.5449606269275988
# (53, 74)
# 573116409370-1578664391 / 573135714229-1525652805
# ['videos & demencias']
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
#
# 0.0
#
# 0.5734225187214794
# (53, 75)
# 573116409370-1578664391 / 573135852009-1585347056
# ['videos & demencias']
# ['Lakrasy fresasde vnzla' 'Hora hott' 'Lakrasy fresas de vnzl'
#  '.Supreme 5.0']
#
# 0.0
#
# 0.6473690422007967
# (53, 81)
# 573116409370-1578664391 / 573145114610-1573649691
# ['videos & demencias']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5183773540419683
# (53, 98)
# 573116409370-1578664391 / 573204896999-1557775885
# ['videos & demencias']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.5592338582848809
# (53, 101)
# 573116409370-1578664391 / 573209056220-1582183315
# ['videos & demencias']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.5525414741763918
# (53, 154)
# 573116409370-1578664391 / 584247393733-1565574033
# ['videos & demencias']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.5578437716835144
# (53, 161)
# 573116409370-1578664391 / 584264954187-1584036417
# ['videos & demencias']
# ['Salsa baul.']
#
# 0.0
#
# 0.5942144820988712
# (53, 177)
# 573116409370-1578664391 / ba66fc9b8d17ec54b9a0546008fc7812
# ['videos & demencias']
# ['videos & demencias']
#
# MERGE
#
# 0.6905853511651427
# (56, 120)
# 573118275688-1574895740 / 573505077552-1573850475
# ['XXX CASEROS Y MAS']
# ['Venezuela']
#
# 0.0
#
# 0.542972474734254
# (58, 78)
# 573118547343-1545866247 / 573138303724-1574641574
# ['ServicioViajeros JP &']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5075933932262912
# (58, 121)
# 573118547343-1545866247 / 573507846957-1571104076
# ['ServicioViajeros JP &']
# ['Viajando por america' 'Viajando por america…' 'viaja con yoeslin']
#
# 0.0
#
# 0.5161193056489599
# (58, 122)
# 573118547343-1545866247 / 573508650959-1572285131
# ['ServicioViajeros JP &']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.509022358641728
# (58, 126)
# 573118547343-1545866247 / 584124411924-1570375550
# ['ServicioViajeros JP &']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5103357480702334
# (58, 152)
# 573118547343-1545866247 / 584246899964-1572440568
# ['ServicioViajeros JP &']
# ['Venezolanos por migrar']
#
# 0.0
#
# 0.5431423537865828
# (63, 122)
# 573123412936-1556628265 / 573508650959-1572285131
# ['Informa Vzla']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6658011924192946
# (63, 126)
# 573123412936-1556628265 / 584124411924-1570375550
# ['Informa Vzla']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.522352173815325
# (63, 131)
# 573123412936-1556628265 / 584144043691-1548595172
# ['Informa Vzla']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5022295867533815
# (63, 137)
# 573123412936-1556628265 / 584164805353-1497744666
# ['Informa Vzla']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5315821611812375
# (65, 73)
# 573124347578-1563538654 / 573134508951-1549727034
# ['41RED DE APOYO']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.5605443673228122
# (65, 78)
# 573124347578-1563538654 / 573138303724-1574641574
# ['41RED DE APOYO']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.5038591075394077
# (65, 126)
# 573124347578-1563538654 / 584124411924-1570375550
# ['41RED DE APOYO']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5252184878647932
# (65, 130)
# 573124347578-1563538654 / 584143426635-1560226365
# ['41RED DE APOYO']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.581073146317236
# (65, 131)
# 573124347578-1563538654 / 584144043691-1548595172
# ['41RED DE APOYO']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.520694271652965
# (65, 137)
# 573124347578-1563538654 / 584164805353-1497744666
# ['41RED DE APOYO']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5066029945051825
# (69, 73)
# 573126571743-1576515287 / 573134508951-1549727034
# ['Venezuela Hermosa']
# ['Tv Libre Noticias']
#
# 0.0
#
# 0.6061257090894658
# (69, 78)
# 573126571743-1576515287 / 573138303724-1574641574
# ['Venezuela Hermosa']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.003780718336483932
#
# 0.5563796518950627
# (69, 86)
# 573126571743-1576515287 / 573164027951-1528740794
# ['Venezuela Hermosa']
# ['Busca tu empleo,cali …' 'Busca tu empleo,cali']
#
# 0.0
#
# 0.5247479129440115
# (69, 89)
# 573126571743-1576515287 / 573183047597-1573740920
# ['Venezuela Hermosa']
# ['#2 busca tu empleo Cali']
#
# 0.0
#
# 0.517688313517734
# (69, 122)
# 573126571743-1576515287 / 573508650959-1572285131
# ['Venezuela Hermosa']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.5572322316808368
# (69, 126)
# 573126571743-1576515287 / 584124411924-1570375550
# ['Venezuela Hermosa']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.50968982598579
# (69, 130)
# 573126571743-1576515287 / 584143426635-1560226365
# ['Venezuela Hermosa']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.52544507473489
# (69, 131)
# 573126571743-1576515287 / 584144043691-1548595172
# ['Venezuela Hermosa']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5122731136200215
# (69, 137)
# 573126571743-1576515287 / 584164805353-1497744666
# ['Venezuela Hermosa']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5289107357437757
# (70, 120)
# 573127205208-1577591043 / 573505077552-1573850475
# ['']
# ['Venezuela']
#
# 0.0
#
# 0.5841438944047065
# (71, 81)
# 573132354041-1558060453 / 573145114610-1573649691
# ['El Renacimiento']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5008534910215737
# (71, 101)
# 573132354041-1558060453 / 573209056220-1582183315
# ['El Renacimiento']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.6371899976843463
# (71, 168)
# 573132354041-1558060453 / 85b07927cac67371a7fad783185e3c98
# ['El Renacimiento']
# ['En busca del amor']
# 0.0
#
# 0.6371899976843463
# (71, 174)
# 573132354041-1558060453 / 98e09c58f6c8dadb5a0718470da8e78a
# ['El Renacimiento']
# ['En busca del amor']
#
# 0.0
#
# 0.6153863571271405
# (71, 178)
# 573132354041-1558060453 / bb5f0162ea905c338130adedd4e0b703
# ['El Renacimiento']
# ['Rumbas en Cali YAYI']
#
# 0.0
#
# 0.6371899976843463
# (71, 182)
# 573132354041-1558060453 / c5b60e71e9324a17027931bab4014e86
# ['El Renacimiento']
# ['En busca del amor']
#
# 0.0
#
# 0.5589602125950446
# (73, 78)
# 573134508951-1549727034 / 573138303724-1574641574
# ['Tv Libre Noticias']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.6460319565538348
# (73, 118)
# 573134508951-1549727034 / 573227727724-1572791992
# ['Tv Libre Noticias']
# ['Venezuela es pasión']
#
# 0.0
#
# 0.5960986175547416
# (73, 122)
# 573134508951-1549727034 / 573508650959-1572285131
# ['Tv Libre Noticias']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.66629096293576
# (73, 126)
# 573134508951-1549727034 / 584124411924-1570375550
# ['Tv Libre Noticias']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.7066688614535767
# (73, 128)
# 573134508951-1549727034 / 584126397289-1585051205
# ['Tv Libre Noticias']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.8269169395735569
# (73, 129)
# 573134508951-1549727034 / 584126863708-1574171158
# ['Tv Libre Noticias']
# ['Venezuela Al Minuto XXXIV']
#
# 0.0
#
# 0.8195688639775358
# (73, 130)
# 573134508951-1549727034 / 584143426635-1560226365
# ['Tv Libre Noticias']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.8363041116030481
# (73, 131)
# 573134508951-1549727034 / 584144043691-1548595172
# ['Tv Libre Noticias']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.7612758836502357
# (73, 137)
# 573134508951-1549727034 / 584164805353-1497744666
# ['Tv Libre Noticias']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5349364842156561
# (74, 78)
# 573135714229-1525652805 / 573138303724-1574641574
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
#
# 0.0
#
# 0.6662592916512491
# (74, 81)
# 573135714229-1525652805 / 573145114610-1573649691
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5335465664169448
# (74, 98)
# 573135714229-1525652805 / 573204896999-1557775885
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.5769019823940847
# (74, 101)
# 573135714229-1525652805 / 573209056220-1582183315
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.5701094962694097
# (74, 154)
# 573135714229-1525652805 / 584247393733-1565574033
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.5343398026946216
# (74, 161)
# 573135714229-1525652805 / 584264954187-1584036417
# ['VENTAS - EMPLEO - ARRIEDO' 'COMUNIDAD SW CALI']
# ['Salsa baul.']
#
# 0.0
#
# 0.6320813197526894
# (75, 81)
# 573135852009-1585347056 / 573145114610-1573649691
# ['Lakrasy fresasde vnzla' 'Hora hott' 'Lakrasy fresas de vnzl'
#  '.Supreme 5.0']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5132187750544508
# (75, 101)
# 573135852009-1585347056 / 573209056220-1582183315
# ['Lakrasy fresasde vnzla' 'Hora hott' 'Lakrasy fresas de vnzl'
#  '.Supreme 5.0']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.5253623525383015
# (75, 154)
# 573135852009-1585347056 / 584247393733-1565574033
# ['Lakrasy fresasde vnzla' 'Hora hott' 'Lakrasy fresas de vnzl'
#  '.Supreme 5.0']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.506024126162915
# (75, 161)
# 573135852009-1585347056 / 584264954187-1584036417
# ['Lakrasy fresasde vnzla' 'Hora hott' 'Lakrasy fresas de vnzl'
#  '.Supreme 5.0']
# ['Salsa baul.']
#
# 0.0
#
# 0.5660417207935446
# (78, 80)
# 573138303724-1574641574 / 573144119145-1579414437
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['VENEZOLANOS UNIDOS' 'VENEZOLANOS UNIDOS…']
#
# 0.0
#
# 0.5182924341492237
# (78, 81)
# 573138303724-1574641574 / 573145114610-1573649691
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
#
# 0.0
#
# 0.5163301165595859
# (78, 98)
# 573138303724-1574641574 / 573204896999-1557775885
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.5293063560689865
# (78, 105)
# 573138303724-1574641574 / 573213514329-1575474764
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['El Mercadito Venezolano']
#
# 0.0
#
# 0.6300561400489483
# (78, 122)
# 573138303724-1574641574 / 573508650959-1572285131
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6083990814991314
# (78, 126)
# 573138303724-1574641574 / 584124411924-1570375550
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5363216457439243
# (78, 128)
# 573138303724-1574641574 / 584126397289-1585051205
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.5849423043465962
# (78, 130)
# 573138303724-1574641574 / 584143426635-1560226365
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.5565041832229501
# (78, 131)
# 573138303724-1574641574 / 584144043691-1548595172
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.534014890025474
# (78, 137)
# 573138303724-1574641574 / 584164805353-1497744666
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.61427150486688
# (78, 152)
# 573138303724-1574641574 / 584246899964-1572440568
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['Venezolanos por migrar']
#
# 0.0
#
# 0.5109253026025135
# (78, 154)
# 573138303724-1574641574 / 584247393733-1565574033
# ['Los Panas de Medellín …' 'Los Panas de Medellín']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.6115446267952225
# (79, 86)
# 573143984854-1536331720 / 573164027951-1528740794
# ['Academia de seguridad privada' 'Academia de seguridad privada…']
# ['Busca tu empleo,cali …' 'Busca tu empleo,cali']
#
# 0.0
#
# 0.5854026379332187
# (79, 89)
# 573143984854-1536331720 / 573183047597-1573740920
# ['Academia de seguridad privada' 'Academia de seguridad privada…']
# ['#2 busca tu empleo Cali']
#
# 0.0
#
# 0.5005544177610779
# (80, 101)
# 573144119145-1579414437 / 573209056220-1582183315
# ['VENEZOLANOS UNIDOS' 'VENEZOLANOS UNIDOS…']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.6013313478554196
# (81, 83)
# 573145114610-1573649691 / 573153334741-1583452605
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
# ['ESTADOS DE WHATSAPP' 'ESTADOS DE WHATSAPP…']
#
# 0.0
#
# 0.5772872612328426
# (81, 98)
# 573145114610-1573649691 / 573204896999-1557775885
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
#
# 0.0
#
# 0.65715113964367
# (81, 101)
# 573145114610-1573649691 / 573209056220-1582183315
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
# ['SalsaBaul ineditas']
#
# 0.0
#
# 0.6596310446170884
# (81, 154)
# 573145114610-1573649691 / 584247393733-1565574033
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.6059860304990867
# (81, 161)
# 573145114610-1573649691 / 584264954187-1584036417
# ['Fotos y videos xxx' 'GRUPO  DE DESPARCHE…' 'GRUPO  DE DESPARCHE']
# ['Salsa baul.']
#
# 0.0
#
# 0.5062567841074108
# (83, 120)
# 573153334741-1583452605 / 573505077552-1573850475
# ['ESTADOS DE WHATSAPP' 'ESTADOS DE WHATSAPP…']
# ['Venezuela']
#
# 0.0
#
# 0.9692122945879559
# (86, 89)
# 573164027951-1528740794 / 573183047597-1573740920
# ['Busca tu empleo,cali …' 'Busca tu empleo,cali']
# ['#2 busca tu empleo Cali']
#
# 0.37547892720306514
#
# 0.509380889586845
# (86, 172)
# 573164027951-1528740794 / 969c6e9df3cddef9c9096cfddc848705
# ['Busca tu empleo,cali …' 'Busca tu empleo,cali']
# ['EMPLEO VENEZOLANOS']
#
# 0.0
#
# 0.5002429824224404
# (89, 172)
# 573183047597-1573740920 / 969c6e9df3cddef9c9096cfddc848705
# ['#2 busca tu empleo Cali']
# ['EMPLEO VENEZOLANOS']
#
# 0.0
#
# 0.5340504047583774
# (90, 121)
# 573185484739-1578495272 / 573507846957-1571104076
# ['VIAJES LATINOAMERICA 2' 'VIAJES LATINOAMERICA 2…']
# ['Viajando por america' 'Viajando por america…' 'viaja con yoeslin']
#
# 0.0
#
# 0.5366451628748141
# (90, 159)
# 573185484739-1578495272 / 584249162644-1575917113
# ['VIAJES LATINOAMERICA 2' 'VIAJES LATINOAMERICA 2…']
# ['VIAJES JOSE MILLAN' 'VIAJES  MILLAN Y REMESAS']
#
# 0.0
#
# 0.5352425151217718
# (90, 162)
# 573185484739-1578495272 / 5fec47ed4dc43982ac4e647aaecc48a2
# ['VIAJES LATINOAMERICA 2' 'VIAJES LATINOAMERICA 2…']
# ['VIAJES LATINOAMERICA 2']
#
# MERGE
#
# 0.5194728538664739
# (97, 103)
# 573204379940-1516889957 / 573209868284-1574208253
# ['Nacional de Cambios  .']
# ['Compra Y Ventas De Autos']
# 0.0
#
# 0.5404288269829839
# (97, 148)
# 573204379940-1516889957 / 584245066057-1546970262
# ['Nacional de Cambios  .']
# ['CAMBIOS IP' 'Cambios IP']
#
# 0.0
#
# 0.6145590755487262
# (97, 151)
# 573204379940-1516889957 / 584246249002-1565349721
# ['Nacional de Cambios  .']
# ['CASA DE CAMBIOS D&Y' 'CASA DE CAMBIOS D&Y…']
#
# 0.0
#
# 0.5199943388383801
# (98, 154)
# 573204896999-1557775885 / 584247393733-1565574033
# ['>AMIGS SIN FRNTERAS<' '>AMIGS SIN FRNTERAS<…']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.5655496497658977
# (101, 154)
# 573209056220-1582183315 / 584247393733-1565574033
# ['SalsaBaul ineditas']
# ['GENTE CHEVERE']
#
# 0.0
#
# 0.6797052452927306
# (101, 161)
# 573209056220-1582183315 / 584264954187-1584036417
# ['SalsaBaul ineditas']
# ['Salsa baul.']
#
# 0.0
#
# 0.9106251233706617
# (104, 167)
# 573212644564-1549511812 / 85700215ac095301c08be263a8e96d4a
# ['StarCambioS']
# ['StarCambioS']
#
# MERGE
#
# 0.7176665064071458
# (105, 118)
# 573213514329-1575474764 / 573227727724-1572791992
# ['El Mercadito Venezolano']
# ['Venezuela es pasión']
#
# 0.0617678381256656
#
# 0.5566777599087979
# (105, 122)
# 573213514329-1575474764 / 573508650959-1572285131
# ['El Mercadito Venezolano']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.5178326220103333
# (105, 126)
# 573213514329-1575474764 / 584124411924-1570375550
# ['El Mercadito Venezolano']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.8701913972224675
# (116, 125)
# 573225356605-1579036426 / 584124402682-1551884675
# ['Mochileros.en.manos.de.']
# ['@CambiosRemVenz 1']
#
# 0.0
#
# 0.8743050561274764
# (116, 147)
# 573225356605-1579036426 / 584243846359-1564139863
# ['Mochileros.en.manos.de.']
# ['@CambiosRemVenz 2']
#
# 0.0
#
# 0.5638156637652157
# (118, 122)
# 573227727724-1572791992 / 573508650959-1572285131
# ['Venezuela es pasión']
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
#
# 0.0
#
# 0.6114474490948525
# (118, 126)
# 573227727724-1572791992 / 584124411924-1570375550
# ['Venezuela es pasión']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5822027931203391
# (118, 128)
# 573227727724-1572791992 / 584126397289-1585051205
# ['Venezuela es pasión']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.5292721153228018
# (118, 129)
# 573227727724-1572791992 / 584126863708-1574171158
# ['Venezuela es pasión']
# ['Venezuela Al Minuto XXXIV']
#
# 0.0
#
# 0.6614993414059089
# (118, 130)
# 573227727724-1572791992 / 584143426635-1560226365
# ['Venezuela es pasión']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.08852459016393442
#
# 0.6667911589681372
# (118, 131)
# 573227727724-1572791992 / 584144043691-1548595172
# ['Venezuela es pasión']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.6310919068469597
# (118, 137)
# 573227727724-1572791992 / 584164805353-1497744666
# ['Venezuela es pasión']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.6804740321029384
# (122, 126)
# 573508650959-1572285131 / 584124411924-1570375550
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
# ['Venezuela y Colombia']
#
# 0.0
#
# 0.5692063501147432
# (122, 128)
# 573508650959-1572285131 / 584126397289-1585051205
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.6210266774247042
# (122, 130)
# 573508650959-1572285131 / 584143426635-1560226365
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.6055717814070463
# (122, 131)
# 573508650959-1572285131 / 584144043691-1548595172
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.5725551938888944
# (122, 137)
# 573508650959-1572285131 / 584164805353-1497744666
# ['CUCUTA^Paso^FRONTERA' 'CUCUTA^Paso^FRONTERA…']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.9964665130086006
# (125, 147)
# 584124402682-1551884675 / 584243846359-1564139863
# ['@CambiosRemVenz 1']
# ['@CambiosRemVenz 2']
#
# 0.33636363636363636
#
# 0.6838943283475861
# (126, 128)
# 584124411924-1570375550 / 584126397289-1585051205
# ['Venezuela y Colombia']
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
#
# 0.0
#
# 0.5304439504561743
# (126, 129)
# 584124411924-1570375550 / 584126863708-1574171158
# ['Venezuela y Colombia']
# ['Venezuela Al Minuto XXXIV']
#
# 0.0
#
# 0.6767362012778046
# (126, 130)
# 584124411924-1570375550 / 584143426635-1560226365
# ['Venezuela y Colombia']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.7019603200331019
# (126, 131)
# 584124411924-1570375550 / 584144043691-1548595172
# ['Venezuela y Colombia']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.6668332871300964
# (126, 137)
# 584124411924-1570375550 / 584164805353-1497744666
# ['Venezuela y Colombia']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5057615279123236
# (126, 142)
# 584124411924-1570375550 / 584167881770-1573754266
# ['Venezuela y Colombia']
# ['16 DE NOV#VENEZUELA LIBRE']
#
# 0.0
#
# 0.6034008648899378
# (128, 129)
# 584126397289-1585051205 / 584126863708-1574171158
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
# ['Venezuela Al Minuto XXXIV']
#
# 0.0
#
# 0.7434809100229022
# (128, 130)
# 584126397289-1585051205 / 584143426635-1560226365
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.12351778656126482
#
# 0.7500909697339845
# (128, 131)
# 584126397289-1585051205 / 584144043691-1548595172
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.6748169641958588
# (128, 137)
# 584126397289-1585051205 / 584164805353-1497744666
# ['Venezolano en el mundo' 'Venezolanos en el mundo']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.6719272437093635
# (129, 130)
# 584126863708-1574171158 / 584143426635-1560226365
# ['Venezuela Al Minuto XXXIV']
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
#
# 0.0
#
# 0.7822460957804935
# (129, 131)
# 584126863708-1574171158 / 584144043691-1548595172
# ['Venezuela Al Minuto XXXIV']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.6442945725457498
# (129, 137)
# 584126863708-1574171158 / 584164805353-1497744666
# ['Venezuela Al Minuto XXXIV']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.8391758994765568
# (130, 131)
# 584143426635-1560226365 / 584144043691-1548595172
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
# ['*NOTICIAS VZLA *']
#
# 0.0
#
# 0.7777026064302333
# (130, 137)
# 584143426635-1560226365 / 584164805353-1497744666
# ['CÚCUTA L.Q.T.D.S' 'CÚCUTA L.Q.T.D.S …' 'CÚCUTA EN FRONTERA C.V'
#  'CÚCUTA EN FRONTERA C.V…']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.8269134441969664
# (131, 137)
# 584144043691-1548595172 / 584164805353-1497744666
# ['*NOTICIAS VZLA *']
# ['venezuela informa…' 'venezuela informa']
#
# 0.0
#
# 0.5251462613106763
# (138, 148)
# 584165720056-1570975871 / 584245066057-1546970262
# ['C&C Cambios 6']
# ['CAMBIOS IP' 'Cambios IP']
#
# 0.0
#
# 0.5675397731347062
# (139, 169)
# 584165759089-1574016643 / 9097e92ff180598e8f0ef8ce2a7cf124
# ['CARACOLES DE ÒŞÀ BOGOTA']
# ['CARACOLES DE ÒŞÀ BOGOTA']
#
# MERGE
#
# 0.5675397731347062
# (139, 171)
# 584165759089-1574016643 / 948cff1b59095b64bc9b6a3ff511095b
# ['CARACOLES DE ÒŞÀ BOGOTA']
# ['CARACOLES DE ÒŞÀ BOGOTA']
#
# MERGE
#
# 0.5129643063836875
# (154, 161)
# 584247393733-1565574033 / 584264954187-1584036417
# ['GENTE CHEVERE']
# ['Salsa baul.']
#
# 0.0
#
# 0.8877543177503293
# (163, 188)
# 637b95ab907e5a297d5ef9d5e60bd782 / f1797448aa037adba849c037ca9f5c9c
# ['Vnzlns rumberos Medellín']
# ['Vnzlns rumberos Medellín']
#
# MERGE
#
# 1.0
# (168, 174)
# 85b07927cac67371a7fad783185e3c98 / 98e09c58f6c8dadb5a0718470da8e78a
# ['En busca del amor']
# ['En busca del amor']
#
# 0.0
#
# 0.5071363299371358
# (168, 178)
# 85b07927cac67371a7fad783185e3c98 / bb5f0162ea905c338130adedd4e0b703
# ['En busca del amor']
# ['Rumbas en Cali YAYI']
#
# 0.0
#
# 1.0
# (168, 182)
# 85b07927cac67371a7fad783185e3c98 / c5b60e71e9324a17027931bab4014e86
# ['En busca del amor']
# ['En busca del amor']
#
# 0.0
#
# 1.0
# (169, 171)
# 9097e92ff180598e8f0ef8ce2a7cf124 / 948cff1b59095b64bc9b6a3ff511095b
# ['CARACOLES DE ÒŞÀ BOGOTA']
# ['CARACOLES DE ÒŞÀ BOGOTA']
#
# MERGE
#
# 0.5071363299371358
# (174, 178)
# 98e09c58f6c8dadb5a0718470da8e78a / bb5f0162ea905c338130adedd4e0b703
# ['En busca del amor']
# ['Rumbas en Cali YAYI']
#
# 0.0
#
# 1.0
# (174, 182)
# 98e09c58f6c8dadb5a0718470da8e78a / c5b60e71e9324a17027931bab4014e86
# ['En busca del amor']
# ['En busca del amor']
#
# MERGE
#
# 0.5071363299371358
# (178, 182)
# bb5f0162ea905c338130adedd4e0b703 / c5b60e71e9324a17027931bab4014e86
# ['Rumbas en Cali YAYI']
# ['En busca del amor']
# 0.0
#
# 1.0
# (181, 189)
# c156b079eb85b92d5b9d8ebe1d9b6a54 / f4002abec840067e43fb14e866247b5a
# ['Saʟsɛʀօs ɖɛ Cօʀaʐóռ']
# ['Saʟsɛʀօs ɖɛ Cօʀaʐóռ']
#
# MERGE

# %%
print(len(rename_from_to))
print(df_x['uid'].unique().shape[0])
# Out:
# 23
# 191

# %%
with open('Data/intermediate/rename_from_to.txt', 'w') as file:
    file.write(str(rename_from_to))

# %% [markdown]
# ## Fix

# %%
df_x['uid'] = df_x['uid'].replace([i[0] for i in rename_from_to], [i[1] for i in rename_from_to])

# %% [markdown]
# # Remove duplicates again

# %%
# Duplicate messages within same traverse
intra_traverse_duplicates = df_x[df_x.duplicated(keep = False)]

# This gives us all duplicates that have the same timez.
# However, bona fide duplicates may be duplicated across multiple runs of traverse, so we only
# want one appearance of them.

# %%
# We can go through all possible bona fide duplicates
# and mark to keep them iff they are the first run bona fide duplicate

duplicates_first_appearance = []
i_true_duplicates = []
partials_collection = []

for i, row in intra_traverse_duplicates.iterrows():
    row_partial = row[['uid', 'event', 'text', 'emojis',
       'audio_length', 'image', 'reply_to', 'reply_text', 'reply_image',
       'reply_thumb', 'reply_emojis', 'reply_type_audio', 'reply_type_image',
       'message_deleted', 'video_length', 'video_thumb', 'forwarded',
       'forwarded_highly', 'tel', 'message_dt', 'message_date', 'textlower']]

    if str(row.values) in duplicates_first_appearance:
        i_true_duplicates.append(i)        
    else:
        if str(row_partial.values) in partials_collection:
            pass
        else:
            duplicates_first_appearance.append(str(row.values))
            partials_collection.append(str(row_partial.values))
            
print(len(i_true_duplicates))
# Out:
# 1881

# %%
persist_cols = ['uid', 'title', 'event', 'text', 'emojis',
       'audio_length', 'image', 'reply_to', 'reply_text', 'reply_image',
       'reply_thumb', 'reply_emojis', 'reply_type_audio', 'reply_type_image',
       'message_deleted', 'video_length', 'video_thumb', 'forwarded',
       'forwarded_highly', 'tel', 'message_dt', 'message_date', 'textlower']

# %%
i_duplicates = df_x[df_x[persist_cols].duplicated(keep = 'first')].index.values

# %%
i_duplicates_remove = [i for i in i_duplicates if i not in i_true_duplicates]

# %%
print(len(i_duplicates))
print(len(i_duplicates_remove))
# Out:
# 2542
# 661

# %%
df_x = df_x.drop(i_duplicates_remove, axis = 0)
print(df_x.shape)
# Out:
# (171634, 26)

# %%
df_x = df_x.reset_index(drop = True)

# %%
df_x.to_csv("Data/df_x_nb0a-groupMerge.csv")
